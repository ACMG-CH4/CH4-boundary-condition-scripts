# %%
# this jupyter notebook contains example code to analyze, and plot the outputs of the different steps in the boundary condition scripts
import xarray as xr
dailyCH4 = xr.open_dataset("/home/ubuntu/CH4-boundary-condition-scripts/Step3_correct_background/Daily_CH4.nc")
dailyCH4["CH4"][45,:,:].plot(vmin=1740, vmax=1925)

# %%
bias = xr.open_dataset("/home/ubuntu/CH4-boundary-condition-scripts/Step3_correct_background/Bias_4x5_dk_2_updated.nc")
bias["Bias"][30,:,:].plot()
